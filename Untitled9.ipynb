# %%
import numpy as  np 
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
#3D

# %%
ax =plt.axes(projection="3d")
ax.scatter(3,5,7)
plt.show()

# %%
#scatter plot
ax = plt.axes(projection="3d")

x_data = np.random.randint(0,100,(500,))
y_data = np.random.randint(0,100,(500,))
z_data = np.random.randint(0,100,(500,))

ax.scatter(x_data,y_data,z_data)
plt.show()

# %%
ax =plt.axes(projection="3d")

x_data = np.random.randint(0,50,(2,))
y_data = np.random.randint(0,50,(2,))
z_data = np.random.randint(0,50,(2,))

ax.plot(x_data,y_data,z_data)
ax.set_title("dlamini function")
ax.set_xlabel("my funtion is x(cm)")
ax.set_ylabel("my funtion is y(V)")
ax.set_zlabel("my result is x(cm*V)")
plt.show()

# %%
ax =plt.axes(projection="3d")

x_data = np.arrange(0,50,0,1)
y_data = np.arrange(0,50,0,1)
z_data = npsin(x_data) * np.cos(y_data)

ax.plot(x_data,y_data,z_data)
ax.set_title("dlamini function")
ax.set_xlabel("my funtion is x(cm)")
ax.set_ylabel("my funtion is y(V)")
ax.set_zlabel("my result is x(cm*V)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_223/3086964947.py in <cell line: 3>()
#       1 ax =plt.axes(projection="3d")
#       2
# ----> 3 x_data = np.arrange(0,50,0,1)
#       4 y_data = np.arrange(0,50,0,1)
#       5 z_data = npsin(x_data) * np.cos(y_data)
#
# /usr/local/lib/python3.10/site-packages/numpy/__init__.py in __getattr__(attr)
#     309             return Tester
#     310
# --> 311         raise AttributeError("module {!r} has no attribute "
#     312                              "{!r}".format(__name__, attr))
#     313
#
# AttributeError: module 'numpy' has no attribute 'arrange'
